# 70 香酥炸翅
# 71 香辣翅根
# 72 糖醋虾仁
# 73 葱烧豆腐
# 74 蛤蜊酿虾滑
# 75 红烧猪蹄
# 76 卤牛肉
# 77 酱大骨
# 78 香煎牛排
# 79 青椒炒肉
# 80 荷塘小炒
# 81 蛤蜊酿肉
# 82 香芋蒸排骨
# 83 葱香小酥肉
# 84 鹌鹑蛋酿口蘑
# 85 鲍鱼红烧肉
# 86 玉兔奶冻
# 87 香煎萝卜糕
# 88 白灼秋葵
# 89 香菇炒油菜
# 90 青菜梗炒五花肉
# 91 小凉虾
# 92 凉拌面藕
# 93 凉拌包菜
# 94 白玉菇炒西兰花
# ...

# %%
#create lables for different categories 

snack_number = [153,154,155,156,157]
snack = []
for i in snack_number:
    snack.append(receipe_dict[i])
    
soup_number = [124,125,126,127,128,129]
soup = []
for i in soup_number:
    soup.append(receipe_dict[i])
    
noodle_number = [138,139,140,141,142,143,144,145,146]
noodle = []
for i in noodle_number:
    noodle.append(receipe_dict[i])
    
porridge_number = [147,148,149,150,151,152]
porridge = []
for i in porridge_number:
    porridge.append(receipe_dict[i])

breakfast_number = [51,52,158,159,160,161,162]
breakfast_exclusive = []
for i in breakfast_number:
    breakfast_exclusive.append(receipe_dict[i])
breakfast = breakfast_exclusive + porridge + noodle


not_meals = breakfast_number + snack_number + noodle_number 
receipe_dict_copy = receipe_dict
for i in not_meals:
    receipe_dict_copy.pop(i)


meals = []
for i in receipe_dict_copy.values():
    meals.append(i)

# %%
#create a dataframe and the columns are monday to sunday
columns = ['周一', '周二', '周三', '周四', '周五', '周六','周日']
index=['早餐','午餐','晚餐']
df = pd.DataFrame(columns = ['周一', '周二', '周三', '周四', '周五', '周六','周日'],index=['早餐','午餐','晚餐'])

for i in columns:
    df.loc['早餐',i] = breakfast[rd.randint(0,len(breakfast)-1)]

for i in columns:
    if i == '周二' or i == '周三' or i == '周四':
        pass
    else:
        meal_1 = rd.randint(0,len(breakfast)-1)
        meal_2 = rd.randint(0,len(breakfast)-1)
        while meal_2 == meal_1:
            meal_2 = rd.randint(0,len(breakfast)-1)
        df.loc['午餐',i] = [meals[meal_1],meals[meal_2]]
    
for i in columns:
    meal_1 = rd.randint(0,len(breakfast)-1)
    meal_2 = rd.randint(0,len(breakfast)-1)
    while meal_2 == meal_1:
        meal_2 = rd.randint(0,len(breakfast)-1)
    df.loc['晚餐',i] = [meals[meal_1],meals[meal_2]]

# %%
#this cell is used to make some changes to the existing data frame





#convert the data frame to a picture
# Plot the DataFrame as a table
fig, ax = plt.subplots(figsize=(20, 20))  # Adjust the size based on your needs
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

# Save the table as an image
plt.savefig("receipe.png", bbox_inches='tight', dpi=1000)
plt.show()
